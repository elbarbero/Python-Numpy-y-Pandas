# %%
import pandas as pd

# %%
df_temp = pd.DataFrame({"Fecha":["01/01/2021","01/01/2021","01/01/2021","02/01/2021","02/01/2021","02/01/2021"],
                        "Pais":["España","México","Venezuela","España","México","Venezuela"],
                        "Temperatura":[20,25,28,21,None,30]})

# %%
df_temp
# Out:
#         Fecha       Pais  Temperatura
# 0  01/01/2021     España         20.0
# 1  01/01/2021     México         25.0
# 2  01/01/2021  Venezuela         28.0
# 3  02/01/2021     España         21.0
# 4  02/01/2021     México          NaN
# 5  02/01/2021  Venezuela         30.0

# %%
df_temp[df_temp["Temperatura"]>22]
# Out:
#         Fecha       Pais  Temperatura
# 1  01/01/2021     México         25.0
# 2  01/01/2021  Venezuela         28.0
# 5  02/01/2021  Venezuela         30.0

# %%
df_temp[df_temp["Pais"]=="España"]
# Out:
#         Fecha    Pais  Temperatura
# 0  01/01/2021  España         20.0
# 3  02/01/2021  España         21.0

# %%
df_temp[df_temp["Pais"].str.match("España")]
# Out:
#         Fecha    Pais  Temperatura
# 0  01/01/2021  España         20.0
# 3  02/01/2021  España         21.0

# %%
df_temp[df_temp["Fecha"]=="02/01/2021"]
# Out:
#         Fecha       Pais  Temperatura
# 3  02/01/2021     España         21.0
# 4  02/01/2021     México          NaN
# 5  02/01/2021  Venezuela         30.0

# %%
df_temp[(df_temp["Pais"]=="México") & (df_temp["Temperatura"].notnull())]
# Out:
#         Fecha    Pais  Temperatura
# 1  01/01/2021  México         25.0

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
# Fecha          6 non-null object
# Pais           6 non-null object
# Temperatura    5 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 272.0+ bytes

# %% [markdown]
# # Ejercicio

# %%
df = pd.read_csv(r'C:\Users\ivan_pinar\Dropbox\Creación de MOCs\MOC Master Python Análisis de Datos\Datasets\5.8\PEATONES_2020_mod.csv', encoding = "ISO-8859-1",delimiter=";",index_col=2)

# %%
df.head(10)
# Out:
#                       FECHA     HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020  0:00:00     497.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:15:00     244.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:30:00     179.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:45:00     174.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:00:00     131.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:15:00      95.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:30:00       NaN              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:45:00     175.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  2:00:00     149.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  2:15:00     126.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba        40,0           0

# %%
df.shape
# Out:
# (288755, 11)

# %%
df2 = df[(df["FECHA"]>="01/01/2020") & (df["FECHA"]<="01/05/2020")]

# %%
df2
# Out:
#                       FECHA      HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020   0:00:00     497.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:15:00     244.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:30:00     179.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:45:00     174.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   1:00:00     131.0              1.0   Centro
# ...                     ...       ...       ...              ...      ...
# PERM_PEA19_PM01  01/05/2020  22:45:00     568.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:00:00     588.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:15:00     504.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:30:00     554.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:45:00     492.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# ...                           ...     ...            ...
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# ...                                         ...         ...         ...
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
#
# [7481 rows x 11 columns]

# %%
df2 = df2[df2["DISTRITO"].str.contains("Centro")]

# %%
df2
# Out:
#                       FECHA      HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020   0:00:00     497.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:15:00     244.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:30:00     179.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:45:00     174.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   1:00:00     131.0              1.0   Centro
# ...                     ...       ...       ...              ...      ...
# PERM_PEA19_PM01  01/05/2020  22:45:00     568.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:00:00     588.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:15:00     504.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:30:00     554.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:45:00     492.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# ...                           ...     ...            ...
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# ...                                         ...         ...         ...
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
#
# [5178 rows x 11 columns]

# %%
df2 = df[(df["FECHA"]>="01/01/2020") & (df["FECHA"]<="01/05/2020") & (df["DISTRITO"].str.contains("Centro"))]

# %%
df2
# Out:
#                       FECHA      HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020   0:00:00     497.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:15:00     244.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:30:00     179.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:45:00     174.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   1:00:00     131.0              1.0   Centro
# ...                     ...       ...       ...              ...      ...
# PERM_PEA19_PM01  01/05/2020  22:45:00     568.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:00:00     588.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:15:00     504.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:30:00     554.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:45:00     492.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# ...                           ...     ...            ...
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# ...                                         ...         ...         ...
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
#
# [5178 rows x 11 columns]

# %%
df2.count()
# Out:
# FECHA                      5178
# HORA                       5178
# PEATONES                   5176
# NÚMERO_DISTRITO            5178
# DISTRITO                   5178
# NOMBRE_VIAL                5178
# NÚMERO                     5178
# CÓDIGO_POSTAL              5178
# OBSERVACIONES_DIRECCION    5178
# LATITUD                    5178
# LONGITUD                   5178
# dtype: int64

# %%
df2.head(10)
# Out:
#                       FECHA     HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020  0:00:00     497.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:15:00     244.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:30:00     179.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:45:00     174.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:00:00     131.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:15:00      95.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:30:00       NaN              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:45:00     175.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  2:00:00     149.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  2:15:00     126.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba        40,0           0

# %%
df_interp = df2.interpolate(method ='linear', limit_direction ='forward')

# %%
df_interp.count()
# Out:
# FECHA                      5178
# HORA                       5178
# PEATONES                   5178
# NÚMERO_DISTRITO            5178
# DISTRITO                   5178
# NOMBRE_VIAL                5178
# NÚMERO                     5178
# CÓDIGO_POSTAL              5178
# OBSERVACIONES_DIRECCION    5178
# LATITUD                    5178
# LONGITUD                   5178
# dtype: int64

# %%
df_interp.head(10)
# Out:
#                       FECHA     HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020  0:00:00     497.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:15:00     244.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:30:00     179.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:45:00     174.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:00:00     131.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:15:00      95.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:30:00     135.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:45:00     175.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  2:00:00     149.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  2:15:00     126.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba        40,0           0
