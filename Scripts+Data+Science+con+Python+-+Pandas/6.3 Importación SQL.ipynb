# %%
import pyodbc

# %%
import pandas as pd

# %%
from sqlalchemy import create_engine
import pymysql

# %% [markdown]
# # Importación BBDD MySQL

# %%
db_conexion = create_engine('mysql+pymysql://root:xxxxxx@127.0.0.1/datawarehouse')

# %%
df = pd.read_sql('SELECT * FROM ventas_acumulada', con=db_conexion)

# %%
df
# Out:
#        Order Number Cantidad Pedido Order Line Number  Ventas  \
# 0             10100            49.0               1.0    1689
# 1             10100            50.0               2.0    3390
# 2             10100            30.0               3.0    5151
# 3             10100            22.0               4.0    1903
# 4             10101            26.0               1.0    3773
# ...             ...             ...               ...     ...
# 44793         10416            94.0               6.0    8331
# 44794         10416            74.0               8.0    3843
# 44795         10416            78.0              10.0    5242
# 44796         10416            86.0              12.0    5348
# 44797         10416            48.0              14.0    8704
#
#               Fecha Pedido   Estado         Ciudad           País  \
# 0      2020-06-01 00:00:00  Shipped         Nashua  United States
# 1      2020-06-01 00:00:00  Shipped         Nashua  United States
# ...

# %% [markdown]
# # Importación SQL Server

# %%
import pyodbc
import pandas as pd

# %%
# 1 CREATE CONNECTION
con = pyodbc.connect("DRIVER={SQL Server}; SERVER=IP; DATABASE=nombre_BBDD; UID=user; PWD=password")

# %%
# 2 FIND TABLES INTO BBDD
cursor = con.cursor()
for row in cursor.tables():
    print(row.table_name)

# %%
# 3 RETRIEVE INFO
df = pd.read_sql("select * from table where condicion", con)
