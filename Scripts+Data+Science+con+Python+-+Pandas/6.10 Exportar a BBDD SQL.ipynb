# %%
import pandas as pd

# %%
df_sp500 = pd.read_excel(r'C:\Users\ivan_pinar\Dropbox\Creación de MOCs\MOC Master Python Análisis de Datos\Datasets\6.10\SP500_v2.xlsx',sheet_name="Evolución SP500")
df_sp500["Variación_día"] = (df_sp500["Close"]-df_sp500["Open"])/df_sp500["Open"]*100

# %%
df_sp500
# Out:
#        Unnamed: 0        Date         Open         High          Low  \
# 0               0  1927-12-30    17.660000    17.660000    17.660000
# 1               1  1928-01-03    17.760000    17.760000    17.760000
# 2               2  1928-01-04    17.719999    17.719999    17.719999
# 3               3  1928-01-05    17.549999    17.549999    17.549999
# 4               4  1928-01-06    17.660000    17.660000    17.660000
# ...           ...         ...          ...          ...          ...
# 23186       23186  2020-04-23  2810.419922  2844.899902  2794.260010
# 23187       23187  2020-04-24  2812.639893  2842.709961  2791.760010
# 23188       23188  2020-04-27  2854.649902  2887.719971  2852.889893
# 23189       23189  2020-04-28  2909.959961  2921.149902  2860.709961
# 23190       23190  2020-04-29  2918.459961  2954.860107  2912.159912
#
#              Close    Adj Close      Volume  Variación diaria  Variación_día
# ...

# %%
df_sp500.drop(["Unnamed: 0","Variación diaria"],axis=1,inplace=True)

# %%
df_sp500
# Out:
#              Date         Open         High          Low        Close  \
# 0      1927-12-30    17.660000    17.660000    17.660000    17.660000
# 1      1928-01-03    17.760000    17.760000    17.760000    17.760000
# 2      1928-01-04    17.719999    17.719999    17.719999    17.719999
# 3      1928-01-05    17.549999    17.549999    17.549999    17.549999
# 4      1928-01-06    17.660000    17.660000    17.660000    17.660000
# ...           ...          ...          ...          ...          ...
# 23186  2020-04-23  2810.419922  2844.899902  2794.260010  2797.800049
# 23187  2020-04-24  2812.639893  2842.709961  2791.760010  2836.739990
# 23188  2020-04-27  2854.649902  2887.719971  2852.889893  2878.479980
# 23189  2020-04-28  2909.959961  2921.149902  2860.709961  2863.389893
# 23190  2020-04-29  2918.459961  2954.860107  2912.159912  2939.510010
#
#          Adj Close      Volume  Variación_día
# 0        17.660000           0       0.000000
# ...

# %%
from sqlalchemy import create_engine
import pymysql

# %%
db_conexion = create_engine('mysql+pymysql://root:xxxxxx@127.0.0.1/datawarehouse')

# %%
df_sp500.to_sql(name="sp500_evo",con=db_conexion)
