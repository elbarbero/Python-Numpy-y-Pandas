# %%
import matplotlib.pyplot as plt

# %%
año = [2020, 2021, 2022]

# %%
valor = [5, 7, 9]

# %%
plt.plot(año, valor)

# %%
plt.scatter(año, valor)

# %%
import pandas as pd
df = pd.read_csv(r"E:\Curso Data Science con Python - Numpy & Pandas\Datasets+Data+Science+con+Python+-+Pandas\1.3\Info_pais.csv", encoding = "ISO-8859-1", delimiter = ';')
df.head()
# Out:
#             País   Poblacion  Renta per capita Esperanza de vida
# 0  United States   325084756             59939              78,9
# 1          China  1421021791              8612              76,7
# 2          Japan   127502725             38214              84,5
# 3        Germany    82658409             44680              81,2
# 4          India  1338676785              1980              69,4

# %%
plt.plot(df.head()["País"], df.head()["Esperanza de vida"])
plt.show()

# %%
df = pd.read_csv(r"E:\Curso Data Science con Python - Numpy & Pandas\Datasets+Data+Science+con+Python+-+Pandas\1.3\Info_pais.csv", encoding = "ISO-8859-1", delimiter = ';')
df.index = df["País"]
head = df.head(15)
head
head["Poblacion"].plot()
# Out:
# <Axes: xlabel='País'>

# %%
df.head().plot()
plt.show()

# %%
head = df.head(10)
plt.scatter(head["Renta per capita"],head["Esperanza de vida"])
plt.title("Renta per capita vs Esperanza de vida")
plt.xlabel("Renta per capita")
plt.ylabel("Esperanza de vida")
# Out:
# Text(0, 0.5, 'Esperanza de vida')

# %%
df_sp500 = pd.read_csv(r"E:\Curso Data Science con Python - Numpy & Pandas\Datasets+Data+Science+con+Python+-+Pandas\1.4\SP500_data.csv", encoding = "ISO-8859-1", delimiter = ',')
df_sp500
# Out:
#              Date         Open         High          Low        Close  \
# 0      1927-12-30    17.660000    17.660000    17.660000    17.660000
# 1      1928-01-03    17.760000    17.760000    17.760000    17.760000
# 2      1928-01-04    17.719999    17.719999    17.719999    17.719999
# 3      1928-01-05    17.549999    17.549999    17.549999    17.549999
# 4      1928-01-06    17.660000    17.660000    17.660000    17.660000
# ...           ...          ...          ...          ...          ...
# 23186  2020-04-23  2810.419922  2844.899902  2794.260010  2797.800049
# 23187  2020-04-24  2812.639893  2842.709961  2791.760010  2836.739990
# 23188  2020-04-27  2854.649902  2887.719971  2852.889893  2878.479980
# 23189  2020-04-28  2909.959961  2921.149902  2860.709961  2863.389893
# 23190  2020-04-29  2918.459961  2954.860107  2912.159912  2939.510010
#
#          Adj Close      Volume
# 0        17.660000           0
# 1        17.760000           0
# ...

# %%
df_sp500["Close"].plot()
# Out:
# <Axes: >

# %%
df_sp500.index = df_sp500["Date"]

# %%
df_sp500.head()
# Out:
#                   Date       Open       High        Low      Close  Adj Close  \
# Date
# 1927-12-30  1927-12-30  17.660000  17.660000  17.660000  17.660000  17.660000
# 1928-01-03  1928-01-03  17.760000  17.760000  17.760000  17.760000  17.760000
# 1928-01-04  1928-01-04  17.719999  17.719999  17.719999  17.719999  17.719999
# 1928-01-05  1928-01-05  17.549999  17.549999  17.549999  17.549999  17.549999
# 1928-01-06  1928-01-06  17.660000  17.660000  17.660000  17.660000  17.660000
#
#             Volume
# Date
# 1927-12-30       0
# 1928-01-03       0
# 1928-01-04       0
# 1928-01-05       0
# 1928-01-06       0

# %%
df_sp500["Close"].plot()
# Out:
# <Axes: xlabel='Date'>
