# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"E:\Curso Data Science con Python - Numpy & Pandas\Datasets+Data+Science+con+Python+-+Pandas\1.3\Info_pais.csv", encoding = "ISO-8859-1", delimiter = ';')

# %%
df
# Out:
#                  País   Poblacion  Renta per capita Esperanza de vida
# 0       United States   325084756             59939              78,9
# 1               China  1421021791              8612              76,7
# 2               Japan   127502725             38214              84,5
# 3             Germany    82658409             44680              81,2
# 4               India  1338676785              1980              69,4
# ..                ...         ...               ...               ...
# 163             Samoa      195352              4305              73,2
# 164             Tonga      101998              4193              70,8
# 165             Palau       17808             16275              73,7
# 166  Marshall Islands       58058              3517              73,9
# 167          Kiribati      114158              1626              68,1
#
# [168 rows x 4 columns]

# %%
df.head(10)
# Out:
#              País   Poblacion  Renta per capita Esperanza de vida
# 0   United States   325084756             59939              78,9
# 1           China  1421021791              8612              76,7
# 2           Japan   127502725             38214              84,5
# 3         Germany    82658409             44680              81,2
# 4           India  1338676785              1980              69,4
# 5  United Kingdom    66727461             39532              81,2
# 6          France    64842509             39827              82,5
# 7          Brazil   207833823              9881              75,7
# 8           Italy    60673701             32038              83,6
# 9          Canada    36732095             44841              82,3

# %%
df_order = df.sort_values("Esperanza de vida", ascending = True)

# %%
df_order
# Out:
#                          País  Poblacion  Renta per capita Esperanza de vida
# 151  Central African Republic    4596023               424              52,8
# 149                   Lesotho    2091534              1233              53,7
# 128                      Chad   15016753               657                54
# 143              Sierra Leone    7488423               504              54,3
# 28                    Nigeria  190873244              1969              54,3
# ..                        ...        ...               ...               ...
# 13                      Spain   46647428             28175              83,4
# 8                       Italy   60673701             32038              83,6
# 34                  Singapore    5708041             56746              83,8
# 31                  Hong Kong    7306322             46733              84,1
# 2                       Japan  127502725             38214              84,5
#
# [168 rows x 4 columns]

# %%
df = pd.read_csv(r"E:\Curso Data Science con Python - Numpy & Pandas\Datasets+Data+Science+con+Python+-+Pandas\5.3\PEATONES_2020.csv", encoding = "ISO-8859-1", delimiter = ';', index_col=2)

# %%
df
# Out:
#                       FECHA      HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020   0:00:00       497              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:15:00       244              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:30:00       179              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:45:00       174              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   1:00:00       131              1.0   Centro
# ...                     ...       ...       ...              ...      ...
# PERM_PEA19_PM01  30/06/2020  22:45:00       565              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:00:00       415              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:15:00       551              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:30:00       456              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:45:00       532              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# ...                           ...     ...            ...
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# ...                                         ...         ...         ...
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
#
# [288749 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 288749 entries, PERM_PEA02_PM01 to PERM_PEA19_PM01
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   FECHA                    288749 non-null  object
#  1   HORA                     288749 non-null  object
#  2   PEATONES                 288749 non-null  int64
#  3   NÚMERO_DISTRITO          284866 non-null  float64
#  4   DISTRITO                 284866 non-null  object
#  5   NOMBRE_VIAL              284866 non-null  object
#  6   NÚMERO                   284866 non-null  float64
#  7   CÓDIGO_POSTAL            284866 non-null  float64
#  8   OBSERVACIONES_DIRECCION  284866 non-null  object
#  9   LATITUD                  284866 non-null  object
#  10  LONGITUD                 284866 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 26.4+ MB

# %%
df.iloc[:, [1,3]]
# Out:
#                      HORA  NÚMERO_DISTRITO
# IDENTIFICADOR
# PERM_PEA02_PM01   0:00:00              1.0
# PERM_PEA02_PM01   0:15:00              1.0
# PERM_PEA02_PM01   0:30:00              1.0
# PERM_PEA02_PM01   0:45:00              1.0
# PERM_PEA02_PM01   1:00:00              1.0
# ...                   ...              ...
# PERM_PEA19_PM01  22:45:00              1.0
# PERM_PEA19_PM01  23:00:00              1.0
# PERM_PEA19_PM01  23:15:00              1.0
# PERM_PEA19_PM01  23:30:00              1.0
# PERM_PEA19_PM01  23:45:00              1.0
#
# [288749 rows x 2 columns]

# %%
df.iloc[[2,4,6], [1,3]]
# Out:
#                     HORA  NÚMERO_DISTRITO
# IDENTIFICADOR
# PERM_PEA02_PM01  0:30:00              1.0
# PERM_PEA02_PM01  1:00:00              1.0
# PERM_PEA02_PM01  1:30:00              1.0

# %%
df.loc[["PERM_PEA02_PM01", "PERM_PEA19_PM01"], ["FECHA", "HORA", "NOMBRE_VIAL"]]
# Out:
#                       FECHA      HORA       NOMBRE_VIAL
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020   0:00:00  Calle Fuencarral
# PERM_PEA02_PM01  01/01/2020   0:15:00  Calle Fuencarral
# PERM_PEA02_PM01  01/01/2020   0:30:00  Calle Fuencarral
# PERM_PEA02_PM01  01/01/2020   0:45:00  Calle Fuencarral
# PERM_PEA02_PM01  01/01/2020   1:00:00  Calle Fuencarral
# ...                     ...       ...               ...
# PERM_PEA19_PM01  30/06/2020  22:45:00      Calle Bailén
# PERM_PEA19_PM01  30/06/2020  23:00:00      Calle Bailén
# PERM_PEA19_PM01  30/06/2020  23:15:00      Calle Bailén
# PERM_PEA19_PM01  30/06/2020  23:30:00      Calle Bailén
# PERM_PEA19_PM01  30/06/2020  23:45:00      Calle Bailén
#
# [29036 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 288749 entries, PERM_PEA02_PM01 to PERM_PEA19_PM01
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   FECHA                    288749 non-null  object
#  1   HORA                     288749 non-null  object
#  2   PEATONES                 288749 non-null  int64
#  3   NÚMERO_DISTRITO          284866 non-null  float64
#  4   DISTRITO                 284866 non-null  object
#  5   NOMBRE_VIAL              284866 non-null  object
#  6   NÚMERO                   284866 non-null  float64
#  7   CÓDIGO_POSTAL            284866 non-null  float64
#  8   OBSERVACIONES_DIRECCION  284866 non-null  object
#  9   LATITUD                  284866 non-null  object
#  10  LONGITUD                 284866 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 34.5+ MB

# %%
df.head().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, PERM_PEA02_PM01 to PERM_PEA02_PM01
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   FECHA                    5 non-null      object
#  1   HORA                     5 non-null      object
#  2   PEATONES                 5 non-null      int64
#  3   NÚMERO_DISTRITO          5 non-null      float64
#  4   DISTRITO                 5 non-null      object
#  5   NOMBRE_VIAL              5 non-null      object
#  6   NÚMERO                   5 non-null      float64
#  7   CÓDIGO_POSTAL            5 non-null      float64
#  8   OBSERVACIONES_DIRECCION  5 non-null      object
#  9   LATITUD                  5 non-null      object
#  10  LONGITUD                 5 non-null      object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 480.0+ bytes

# %%
df.describe()
# Out:
#             PEATONES  NÚMERO_DISTRITO         NÚMERO  CÓDIGO_POSTAL
# count  288749.000000    284866.000000  284866.000000  284866.000000
# mean      451.462717         2.648821      27.223291   28010.099685
# std       366.233137         2.999428      24.671669       4.296056
# min         1.000000         1.000000       1.000000   28001.000000
# 25%       142.000000         1.000000       4.000000   28005.000000
# 50%       373.000000         1.000000      22.000000   28012.000000
# 75%       680.000000         2.000000      37.000000   28013.000000
# max      4759.000000        10.000000      91.000000   28015.000000

# %%
df = pd.read_csv(r"E:\Curso Data Science con Python - Numpy & Pandas\Datasets+Data+Science+con+Python+-+Pandas\5.3\PEATONES_2020.csv", encoding = "ISO-8859-1", delimiter = ';', index_col=2)

# %%
df
# Out:
#                       FECHA      HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020   0:00:00       497              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:15:00       244              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:30:00       179              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:45:00       174              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   1:00:00       131              1.0   Centro
# ...                     ...       ...       ...              ...      ...
# PERM_PEA19_PM01  30/06/2020  22:45:00       565              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:00:00       415              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:15:00       551              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:30:00       456              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:45:00       532              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# ...                           ...     ...            ...
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# ...                                         ...         ...         ...
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
#
# [288749 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 288749 entries, PERM_PEA02_PM01 to PERM_PEA19_PM01
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   FECHA                    288749 non-null  object
#  1   HORA                     288749 non-null  object
#  2   PEATONES                 288749 non-null  int64
#  3   NÚMERO_DISTRITO          284866 non-null  float64
#  4   DISTRITO                 284866 non-null  object
#  5   NOMBRE_VIAL              284866 non-null  object
#  6   NÚMERO                   284866 non-null  float64
#  7   CÓDIGO_POSTAL            284866 non-null  float64
#  8   OBSERVACIONES_DIRECCION  284866 non-null  object
#  9   LATITUD                  284866 non-null  object
#  10  LONGITUD                 284866 non-null  object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 26.4+ MB

# %%
df["PEATONES"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 288749 entries, PERM_PEA02_PM01 to PERM_PEA19_PM01
# Series name: PEATONES
# Non-Null Count   Dtype
# --------------   -----
# 288749 non-null  int64
# dtypes: int64(1)
# memory usage: 4.4+ MB

# %%
df["PEATONES"].mean()
# Out:
# 451.4627167539974

# %%
df.describe()
# Out:
#             PEATONES  NÚMERO_DISTRITO         NÚMERO  CÓDIGO_POSTAL
# count  288749.000000    284866.000000  284866.000000  284866.000000
# mean      451.462717         2.648821      27.223291   28010.099685
# std       366.233137         2.999428      24.671669       4.296056
# min         1.000000         1.000000       1.000000   28001.000000
# 25%       142.000000         1.000000       4.000000   28005.000000
# 50%       373.000000         1.000000      22.000000   28012.000000
# 75%       680.000000         2.000000      37.000000   28013.000000
# max      4759.000000        10.000000      91.000000   28015.000000

# %%
print(f"La fecha minima es {df["FECHA"].min()} y la fecha maxima es {df["FECHA"].min()}")
# Out:
# La fecha minima es 01/01/2020 y la fecha maxima es 01/01/2020

# %%
print("La fecha minima es {0} y la fecha maxima es {1}".format(df["FECHA"].min(), df["FECHA"].max()))
# Out:
# La fecha minima es 01/01/2020 y la fecha maxima es 31/05/2020

# %%
df["SUM_PEATONES"] = df["PEATONES"].cumsum()
#for p in df["PEATONES"]:
#    df["SUM_PEATONES"] += p

# %%
df
# Out:
#                       FECHA      HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020   0:00:00       497              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:15:00       244              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:30:00       179              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:45:00       174              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   1:00:00       131              1.0   Centro
# ...                     ...       ...       ...              ...      ...
# PERM_PEA19_PM01  30/06/2020  22:45:00       565              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:00:00       415              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:15:00       551              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:30:00       456              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:45:00       532              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# ...                           ...     ...            ...
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# ...                                         ...         ...         ...
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
#
#                  SUM_PEATONES
# IDENTIFICADOR
# PERM_PEA02_PM01           497
# PERM_PEA02_PM01           741
# PERM_PEA02_PM01           920
# PERM_PEA02_PM01          1094
# PERM_PEA02_PM01          1225
# ...                       ...
# PERM_PEA19_PM01     130357454
# PERM_PEA19_PM01     130357869
# PERM_PEA19_PM01     130358420
# PERM_PEA19_PM01     130358876
# PERM_PEA19_PM01     130359408
#
# [288749 rows x 12 columns]

# %%
df = pd.read_csv(r"E:\Curso Data Science con Python - Numpy & Pandas\Datasets+Data+Science+con+Python+-+Pandas\5.5\PEATONES_2020_mod.csv", encoding = "ISO-8859-1", delimiter = ';', index_col=2)

# %%
df.head()
# Out:
#                       FECHA     HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020  0:00:00     497.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:15:00     244.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:30:00     179.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:45:00     174.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:00:00     131.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 288755 entries, PERM_PEA02_PM01 to PERM_PEA19_PM01
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   FECHA                    288755 non-null  object
#  1   HORA                     288755 non-null  object
#  2   PEATONES                 288752 non-null  float64
#  3   NÚMERO_DISTRITO          284872 non-null  float64
#  4   DISTRITO                 284872 non-null  object
#  5   NOMBRE_VIAL              284872 non-null  object
#  6   NÚMERO                   284872 non-null  float64
#  7   CÓDIGO_POSTAL            284872 non-null  float64
#  8   OBSERVACIONES_DIRECCION  284872 non-null  object
#  9   LATITUD                  284872 non-null  object
#  10  LONGITUD                 284872 non-null  object
# dtypes: float64(4), object(7)
# memory usage: 26.4+ MB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
original_rows = df.shape[0]
print(f"Número de filas: {original_rows}")
# Out:
# Número de filas: 288755

# %%
df.drop_duplicates()
# Out:
#                       FECHA      HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020   0:00:00     497.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:15:00     244.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:30:00     179.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:45:00     174.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   1:00:00     131.0              1.0   Centro
# ...                     ...       ...       ...              ...      ...
# PERM_PEA19_PM01  30/06/2020  22:45:00     565.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:00:00     415.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:15:00     551.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:30:00     456.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:45:00     532.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# ...                           ...     ...            ...
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# ...                                         ...         ...         ...
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
#
# [288749 rows x 11 columns]

# %%
df.shape
# Out:
# (288755, 11)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
filas_sin_duplicar = df.shape[0]
duplicated_rows = original_rows-df.shape[0]

# %%
print(f"Número de filas totales: {original_rows}, de las cuales hay {duplicated_rows} filas duplicadas")
# Out:
# Número de filas totales: 288755, de las cuales hay 6 filas duplicadas

# %%
df.dropna(inplace=True)

# %%
df.shape
wrong_rows = original_rows-df.shape[0]

# %%
print(f"Número de filas totales sin duplicar: {filas_sin_duplicar}, de las cuales hay {wrong_rows} filas erroneas")
# Out:
# Número de filas totales sin duplicar: 288749, de las cuales hay 3892 filas erroneas

# %% [markdown]
# print(f"El {round((wrong_rows/original_rows)*100, 4)} % de los registros son erroneos")

# %%
df2= pd.read_csv(r"E:\Curso Data Science con Python - Numpy & Pandas\Datasets+Data+Science+con+Python+-+Pandas\5.5\PEATONES_2020_mod.csv", encoding = "ISO-8859-1", delimiter = ';', index_col=2)

# %%
df2.head()
# Out:
#                       FECHA     HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020  0:00:00     497.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:15:00     244.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:30:00     179.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:45:00     174.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:00:00     131.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917

# %%
df2[(df2["FECHA"] >= "01/01/2020") & (df2["FECHA"] <= "01/05/2020")]
# Out:
#                       FECHA      HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020   0:00:00     497.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:15:00     244.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:30:00     179.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:45:00     174.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   1:00:00     131.0              1.0   Centro
# ...                     ...       ...       ...              ...      ...
# PERM_PEA19_PM01  01/05/2020  22:45:00     568.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:00:00     588.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:15:00     504.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:30:00     554.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:45:00     492.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# ...                           ...     ...            ...
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# ...                                         ...         ...         ...
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
#
# [7481 rows x 11 columns]

# %%
df_filtered = df2[df2["FECHA"] >= "01/05/2020"]
df_filtered
# Out:
#                       FECHA      HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  02/01/2020   0:00:00     406.0              1.0   Centro
# PERM_PEA02_PM01  02/01/2020   0:15:00     273.0              1.0   Centro
# PERM_PEA02_PM01  02/01/2020   0:30:00     208.0              1.0   Centro
# PERM_PEA02_PM01  02/01/2020   0:45:00     250.0              1.0   Centro
# PERM_PEA02_PM01  02/01/2020   1:00:00     144.0              1.0   Centro
# ...                     ...       ...       ...              ...      ...
# PERM_PEA19_PM01  30/06/2020  22:45:00     565.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:00:00     415.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:15:00     551.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:30:00     456.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:45:00     532.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# ...                           ...     ...            ...
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# ...                                         ...         ...         ...
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
#
# [283002 rows x 11 columns]

# %%
type(df2["DISTRITO"].str)
# Out:
# pandas.core.strings.accessor.StringMethods

# %%
df2[df2["DISTRITO"].str.contains('Centro', regex=False, na = False)]
# Out:
#                       FECHA      HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020   0:00:00     497.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:15:00     244.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:30:00     179.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:45:00     174.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   1:00:00     131.0              1.0   Centro
# ...                     ...       ...       ...              ...      ...
# PERM_PEA19_PM01  30/06/2020  22:45:00     565.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:00:00     415.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:15:00     551.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:30:00     456.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:45:00     532.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# ...                           ...     ...            ...
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# ...                                         ...         ...         ...
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
#
# [193425 rows x 11 columns]

# %%
df2 = df2[(df2["FECHA"] >= "01/01/2020") & (df2["FECHA"] <= "01/05/2020") & (df2["DISTRITO"].str.contains('Centro', regex=False, na = False))]
df2
# Out:
#                       FECHA      HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020   0:00:00     497.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:15:00     244.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:30:00     179.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:45:00     174.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   1:00:00     131.0              1.0   Centro
# ...                     ...       ...       ...              ...      ...
# PERM_PEA19_PM01  01/05/2020  22:45:00     568.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:00:00     588.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:15:00     504.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:30:00     554.0              1.0   Centro
# PERM_PEA19_PM01  01/05/2020  23:45:00     492.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# ...                           ...     ...            ...
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# ...                                         ...         ...         ...
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
#
# [5178 rows x 11 columns]

# %%
total_rows = len(df2.index)
total_rows
df_interpolate = None
if total_rows - int(df2.count()["PEATONES"]) > 0:
    print("Hay valores nulos")
    df2["PEATONES"].fillna(value=round(df2["PEATONES"].mean()), inplace=True)
df2["PEATONES"].mean()
# Out:
# 443.6867516415604

# %%
df2.head(10)
#df_interpolate = df2.interpolate(method='linear', limit_direction = 'forward')
# Out:
#                       FECHA     HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020  0:00:00     497.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:15:00     244.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:30:00     179.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  0:45:00     174.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:00:00     131.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:15:00      95.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:30:00     444.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  1:45:00     175.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  2:00:00     149.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020  2:15:00     126.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba        40,0           0

# %%
df_flowers = pd.read_csv(r"E:\Curso Data Science con Python - Numpy & Pandas\Datasets+Data+Science+con+Python+-+Pandas\5.12\iris_dataset.csv", encoding = "ISO-8859-1", delimiter = ',')

# %%
df_flowers
# Out:
#      longitud_sépalo   anchura_sépalo  longitud_pétalo  anchura_pétalo  \
# 0                5.1              3.5              1.4             0.2
# 1                4.9              3.0              1.4             0.2
# 2                4.7              3.2              1.3             0.2
# 3                4.6              3.1              1.5             0.2
# 4                5.0              3.6              1.4             0.2
# ..               ...              ...              ...             ...
# 145              6.7              3.0              5.2             2.3
# 146              6.3              2.5              5.0             1.9
# 147              6.5              3.0              5.2             2.0
# 148              6.2              3.4              5.4             2.3
# 149              5.9              3.0              5.1             1.8
#
#               clase
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df_flowers = df_flowers.drop('clase', axis=1)
df_flowers
# Out:
#      longitud_sépalo   anchura_sépalo  longitud_pétalo  anchura_pétalo  \
# 0                5.1              3.5              1.4             0.2
# 1                4.9              3.0              1.4             0.2
# 2                4.7              3.2              1.3             0.2
# 3                4.6              3.1              1.5             0.2
# 4                5.0              3.6              1.4             0.2
# ..               ...              ...              ...             ...
# 145              6.7              3.0              5.2             2.3
# 146              6.3              2.5              5.0             1.9
# 147              6.5              3.0              5.2             2.0
# 148              6.2              3.4              5.4             2.3
# 149              5.9              3.0              5.1             1.8
#
#      Area_petalo
# 0       0.879646
# 1       0.879646
# 2       0.816814
# 3       0.942478
# 4       0.879646
# ..           ...
# 145    37.573448
# 146    29.845130
# 147    32.672564
# 148    39.018581
# 149    28.839821
#
# [150 rows x 5 columns]

# %%
df_new = pd.DataFrame(data=(np.pi * df_flowers["longitud_pétalo"] * df_flowers["anchura_pétalo"]), columns=["Area"])

# %%
df_new["longitud_pétalo (mm)"] = df_flowers["longitud_pétalo"]
df_new["anchura_pétalo (mm)"] = df_flowers["anchura_pétalo"]

# %%
df_new
# Out:
#           Area  longitud_pétalo (mm)  anchura_pétalo (mm)
# 0     0.879646                   1.4                  0.2
# 1     0.879646                   1.4                  0.2
# 2     0.816814                   1.3                  0.2
# 3     0.942478                   1.5                  0.2
# 4     0.879646                   1.4                  0.2
# ..         ...                   ...                  ...
# 145  37.573448                   5.2                  2.3
# 146  29.845130                   5.0                  1.9
# 147  32.672564                   5.2                  2.0
# 148  39.018581                   5.4                  2.3
# 149  28.839821                   5.1                  1.8
#
# [150 rows x 3 columns]

# %%
df_flowers["Area_petalo"] = df_flowers.apply(lambda x: (np.pi * x["longitud_pétalo"] * x["anchura_pétalo"]), axis=1)

# %%
df_flowers
# Out:
#      longitud_sépalo   anchura_sépalo  longitud_pétalo  anchura_pétalo  \
# 0                5.1              3.5              1.4             0.2
# 1                4.9              3.0              1.4             0.2
# 2                4.7              3.2              1.3             0.2
# 3                4.6              3.1              1.5             0.2
# 4                5.0              3.6              1.4             0.2
# ..               ...              ...              ...             ...
# 145              6.7              3.0              5.2             2.3
# 146              6.3              2.5              5.0             1.9
# 147              6.5              3.0              5.2             2.0
# 148              6.2              3.4              5.4             2.3
# 149              5.9              3.0              5.1             1.8
#
#               clase  Area_petalo
# 0       Iris-setosa     0.879646
# 1       Iris-setosa     0.879646
# 2       Iris-setosa     0.816814
# 3       Iris-setosa     0.942478
# 4       Iris-setosa     0.879646
# ..              ...          ...
# 145  Iris-virginica    37.573448
# 146  Iris-virginica    29.845130
# 147  Iris-virginica    32.672564
# 148  Iris-virginica    39.018581
# 149  Iris-virginica    28.839821
#
# [150 rows x 6 columns]

# %%
df_flowers["Area_petalo"].median()
# Out:
# 17.64004274990669

# %%
# ¿Qué valor de área solo es superado por el 10% de los petalos?
df_flowers["Area_petalo"].quantile(0.9)
# Out:
# 38.93375775593831

# %%
df_flowers.corr()
# Out:
#                  longitud_sépalo   anchura_sépalo  longitud_pétalo  \
# longitud_sépalo         1.000000        -0.109369         0.871754
#  anchura_sépalo        -0.109369         1.000000        -0.420516
# longitud_pétalo         0.871754        -0.420516         1.000000
# anchura_pétalo          0.817954        -0.356544         0.962757
# Area_petalo             0.857326        -0.280612         0.958472
#
#                  anchura_pétalo  Area_petalo
# longitud_sépalo        0.817954     0.857326
#  anchura_sépalo       -0.356544    -0.280612
# longitud_pétalo        0.962757     0.958472
# anchura_pétalo         1.000000     0.980229
# Area_petalo            0.980229     1.000000

# %%
df_peatones = pd.read_csv(r"E:\Curso Data Science con Python - Numpy & Pandas\Datasets+Data+Science+con+Python+-+Pandas\5.5\PEATONES_2020_mod.csv", encoding = "ISO-8859-1", delimiter = ';', index_col=2)

# %%
df_peatones
# Out:
#                       FECHA      HORA  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# IDENTIFICADOR
# PERM_PEA02_PM01  01/01/2020   0:00:00     497.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:15:00     244.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:30:00     179.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   0:45:00     174.0              1.0   Centro
# PERM_PEA02_PM01  01/01/2020   1:00:00     131.0              1.0   Centro
# ...                     ...       ...       ...              ...      ...
# PERM_PEA19_PM01  30/06/2020  22:45:00     565.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:00:00     415.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:15:00     551.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:30:00     456.0              1.0   Centro
# PERM_PEA19_PM01  30/06/2020  23:45:00     532.0              1.0   Centro
#
#                       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# PERM_PEA02_PM01  Calle Fuencarral    22.0        28004.0
# ...                           ...     ...            ...
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
# PERM_PEA19_PM01      Calle Bailén     6.0        28013.0
#
#                         OBSERVACIONES_DIRECCION     LATITUD    LONGITUD
# IDENTIFICADOR
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# PERM_PEA02_PM01  Calle peatonal Datos en prueba  40,4220090  -3,7008917
# ...                                         ...         ...         ...
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
# PERM_PEA19_PM01     Acera Pares Datos en prueba   40,417278   -3,713371
#
# [288755 rows x 11 columns]

# %%
n_df = df_peatones.groupby("DISTRITO")["PEATONES"].agg("mean")

# %%
df_peatones.groupby(["DISTRITO", "FECHA"])["PEATONES"].agg(["min", "mean"])
# Out:
#                              min        mean
# DISTRITO        FECHA
# Arganzuela      01/01/2020  19.0  589.885417
#                 01/02/2020  34.0  579.602094
#                 01/03/2020  56.0  670.229167
#                 01/04/2020  66.0  573.463542
#                 01/05/2020  47.0  585.791667
# ...                          ...         ...
# Moncloa-Aravaca 30/05/2020  58.0  358.291667
#                 30/06/2020  74.0  261.562500
#                 31/01/2020   6.0  325.760417
#                 31/03/2020   6.0  266.500000
#                 31/05/2020  62.0  447.739583
#
# [860 rows x 2 columns]

# %%
df_peatones.groupby(["DISTRITO", "FECHA"])["PEATONES"].agg(["max", lambda x:x.max()*1.1])
# Out:
#                                max  <lambda_0>
# DISTRITO        FECHA
# Arganzuela      01/01/2020  1577.0      1734.7
#                 01/02/2020  1809.0      1989.9
#                 01/03/2020  1701.0      1871.1
#                 01/04/2020  1501.0      1651.1
#                 01/05/2020  1484.0      1632.4
# ...                            ...         ...
# Moncloa-Aravaca 30/05/2020   643.0       707.3
#                 30/06/2020   691.0       760.1
#                 31/01/2020   762.0       838.2
#                 31/03/2020   697.0       766.7
#                 31/05/2020   786.0       864.6
#
# [860 rows x 2 columns]

# %%
n_df = df_peatones.groupby(["DISTRITO", "FECHA"])["PEATONES"].agg(["max", lambda x:x.max()*1.1]).rename(columns={"max": "MAX PEATONES", "<lambda_0>": "MAX PEATONES + 10%"})

# %%
n_df
# Out:
#                             MAX PEATONES  MAX PEATONES + 10%
# DISTRITO        FECHA
# Arganzuela      01/01/2020        1577.0              1734.7
#                 01/02/2020        1809.0              1989.9
#                 01/03/2020        1701.0              1871.1
#                 01/04/2020        1501.0              1651.1
#                 01/05/2020        1484.0              1632.4
# ...                                  ...                 ...
# Moncloa-Aravaca 30/05/2020         643.0               707.3
#                 30/06/2020         691.0               760.1
#                 31/01/2020         762.0               838.2
#                 31/03/2020         697.0               766.7
#                 31/05/2020         786.0               864.6
#
# [860 rows x 2 columns]

# %%
df_peatones = pd.read_csv(r"E:\Curso Data Science con Python - Numpy & Pandas\Datasets+Data+Science+con+Python+-+Pandas\5.18\PEATONES_2020_mod.csv", encoding = "ISO-8859-1", delimiter = ';')
df_pob = pd.read_csv(r"E:\Curso Data Science con Python - Numpy & Pandas\Datasets+Data+Science+con+Python+-+Pandas\5.18\Distrito_poblacion.csv", encoding = "ISO-8859-1", delimiter = ';')

# %%
df_peatones.head()
# Out:
#         FECHA     HORA    IDENTIFICADOR  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# 0  01/01/2020  0:00:00  PERM_PEA02_PM01     497.0              1.0   Centro
# 1  01/01/2020  0:15:00  PERM_PEA02_PM01     244.0              1.0   Centro
# 2  01/01/2020  0:30:00  PERM_PEA02_PM01     179.0              1.0   Centro
# 3  01/01/2020  0:45:00  PERM_PEA02_PM01     174.0              1.0   Centro
# 4  01/01/2020  1:00:00  PERM_PEA02_PM01     131.0              1.0   Centro
#
#         NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL         OBSERVACIONES_DIRECCION  \
# 0  Calle Fuencarral    22.0        28004.0  Calle peatonal Datos en prueba
# 1  Calle Fuencarral    22.0        28004.0  Calle peatonal Datos en prueba
# 2  Calle Fuencarral    22.0        28004.0  Calle peatonal Datos en prueba
# 3  Calle Fuencarral    22.0        28004.0  Calle peatonal Datos en prueba
# 4  Calle Fuencarral    22.0        28004.0  Calle peatonal Datos en prueba
#
#       LATITUD    LONGITUD
# 0  40,4220090  -3,7008917
# 1  40,4220090  -3,7008917
# 2  40,4220090  -3,7008917
# 3  40,4220090  -3,7008917
# 4  40,4220090  -3,7008917

# %%
df_pob.head()
# Out:
#           DISTRITO  Población_Distrito
# 0       Arganzuela              151965
# 1           Centro              149718
# 2         Chamberí              137401
# 3  Moncloa-Aravaca              116903
# 4           Latina              233808

# %%
df_peatones.groupby(["DISTRITO"])["PEATONES"].agg(["count"]).rename(columns={"count": "POBLACION",})
# Out:
#                  POBLACION
# DISTRITO
# Arganzuela           31539
# Centro              193422
# Chamberí             28411
# Latina               15712
# Moncloa-Aravaca      15785

# %%
df_combinado = df_peatones.merge(df_pob, on="DISTRITO", how="inner")

# %%
df_combinado
# Out:
#              FECHA      HORA    IDENTIFICADOR  PEATONES  NÚMERO_DISTRITO  \
# 0       01/01/2020   0:00:00  PERM_PEA02_PM01     497.0              1.0
# 1       01/01/2020   0:15:00  PERM_PEA02_PM01     244.0              1.0
# 2       01/01/2020   0:30:00  PERM_PEA02_PM01     179.0              1.0
# 3       01/01/2020   0:45:00  PERM_PEA02_PM01     174.0              1.0
# 4       01/01/2020   1:00:00  PERM_PEA02_PM01     131.0              1.0
# ...            ...       ...              ...       ...              ...
# 284867  30/06/2020  22:45:00  PERM_PEA19_PM01     565.0              1.0
# 284868  30/06/2020  23:00:00  PERM_PEA19_PM01     415.0              1.0
# 284869  30/06/2020  23:15:00  PERM_PEA19_PM01     551.0              1.0
# 284870  30/06/2020  23:30:00  PERM_PEA19_PM01     456.0              1.0
# 284871  30/06/2020  23:45:00  PERM_PEA19_PM01     532.0              1.0
#
#        DISTRITO       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# 0        Centro  Calle Fuencarral    22.0        28004.0
# 1        Centro  Calle Fuencarral    22.0        28004.0
# 2        Centro  Calle Fuencarral    22.0        28004.0
# 3        Centro  Calle Fuencarral    22.0        28004.0
# 4        Centro  Calle Fuencarral    22.0        28004.0
# ...         ...               ...     ...            ...
# 284867   Centro      Calle Bailén     6.0        28013.0
# 284868   Centro      Calle Bailén     6.0        28013.0
# 284869   Centro      Calle Bailén     6.0        28013.0
# 284870   Centro      Calle Bailén     6.0        28013.0
# 284871   Centro      Calle Bailén     6.0        28013.0
#
#                OBSERVACIONES_DIRECCION     LATITUD    LONGITUD  \
# 0       Calle peatonal Datos en prueba  40,4220090  -3,7008917
# 1       Calle peatonal Datos en prueba  40,4220090  -3,7008917
# 2       Calle peatonal Datos en prueba  40,4220090  -3,7008917
# 3       Calle peatonal Datos en prueba  40,4220090  -3,7008917
# 4       Calle peatonal Datos en prueba  40,4220090  -3,7008917
# ...                                ...         ...         ...
# 284867     Acera Pares Datos en prueba   40,417278   -3,713371
# 284868     Acera Pares Datos en prueba   40,417278   -3,713371
# 284869     Acera Pares Datos en prueba   40,417278   -3,713371
# 284870     Acera Pares Datos en prueba   40,417278   -3,713371
# 284871     Acera Pares Datos en prueba   40,417278   -3,713371
#
#         Población_Distrito
# 0                   149718
# 1                   149718
# 2                   149718
# 3                   149718
# 4                   149718
# ...                    ...
# 284867              149718
# 284868              149718
# 284869              149718
# 284870              149718
# 284871              149718
#
# [284872 rows x 13 columns]

# %%
df_combinado["KPI_peatones_pobl"] = df_combinado["PEATONES"]/df_combinado["Población_Distrito"]

# %%
df_combinado.head()
# Out:
#         FECHA     HORA    IDENTIFICADOR  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# 0  01/01/2020  0:00:00  PERM_PEA02_PM01     497.0              1.0   Centro
# 1  01/01/2020  0:15:00  PERM_PEA02_PM01     244.0              1.0   Centro
# 2  01/01/2020  0:30:00  PERM_PEA02_PM01     179.0              1.0   Centro
# 3  01/01/2020  0:45:00  PERM_PEA02_PM01     174.0              1.0   Centro
# 4  01/01/2020  1:00:00  PERM_PEA02_PM01     131.0              1.0   Centro
#
#         NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL         OBSERVACIONES_DIRECCION  \
# 0  Calle Fuencarral    22.0        28004.0  Calle peatonal Datos en prueba
# 1  Calle Fuencarral    22.0        28004.0  Calle peatonal Datos en prueba
# 2  Calle Fuencarral    22.0        28004.0  Calle peatonal Datos en prueba
# 3  Calle Fuencarral    22.0        28004.0  Calle peatonal Datos en prueba
# 4  Calle Fuencarral    22.0        28004.0  Calle peatonal Datos en prueba
#
#       LATITUD    LONGITUD  Población_Distrito  KPI_peatones_pobl
# 0  40,4220090  -3,7008917              149718           0.003320
# 1  40,4220090  -3,7008917              149718           0.001630
# 2  40,4220090  -3,7008917              149718           0.001196
# 3  40,4220090  -3,7008917              149718           0.001162
# 4  40,4220090  -3,7008917              149718           0.000875

# %%
df_combinado.groupby(["DISTRITO"])["KPI_peatones_pobl"].agg(["max"]).rename(columns={"max": "max_KPI_peatones_pobl",})
# Out:
#                  max_KPI_peatones_pobl
# DISTRITO
# Arganzuela                    0.026809
# Centro                        0.031786
# Chamberí                      0.008413
# Latina                        0.000920
# Moncloa-Aravaca               0.008811

# %%
from sqlalchemy import create_engine
import pymysql

# %%
db_conection = create_engine("mysql+pymysql://root:root@127.0.0.1/sakila")

# %%
df_film_actor = pd.read_sql("SELECT * FROM film_actor", con = db_conection)
df_actor = pd.read_sql("SELECT * FROM actor", con = db_conection)
df_film = pd.read_sql("SELECT * FROM film", con = db_conection)

# %%
df_film_actor
# Out:
#       actor_id  film_id         last_update
# 0            1        1 2006-02-15 05:05:03
# 1            1       23 2006-02-15 05:05:03
# 2            1       25 2006-02-15 05:05:03
# 3            1      106 2006-02-15 05:05:03
# 4            1      140 2006-02-15 05:05:03
# ...        ...      ...                 ...
# 5457       200      879 2006-02-15 05:05:03
# 5458       200      912 2006-02-15 05:05:03
# 5459       200      945 2006-02-15 05:05:03
# 5460       200      958 2006-02-15 05:05:03
# 5461       200      993 2006-02-15 05:05:03
#
# [5462 rows x 3 columns]

# %%
df_actor
# Out:
#      actor_id first_name     last_name         last_update
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2           3         ED         CHASE 2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..        ...        ...           ...                 ...
# 195       196       BELA        WALKEN 2006-02-15 04:34:33
# 196       197      REESE          WEST 2006-02-15 04:34:33
# 197       198       MARY        KEITEL 2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %%
df_film
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Astounding Epistle of a Database Administrat...          2006
# 2    A Astounding Reflection of a Lumberjack And a ...          2006
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# 996  A Touching Drama of a Teacher And a Cat who mu...          2006
# 997  A Fateful Yarn of a Composer And a Man who mus...          2006
# 998  A Fateful Reflection of a Waitress And a Boat ...          2006
# 999  A Intrepid Panorama of a Mad Scientist And a B...          2006
#
#      language_id original_language_id  rental_duration  rental_rate  length  \
# 0              1                 None                6         0.99      86
# 1              1                 None                3         4.99      48
# 2              1                 None                7         2.99      50
# 3              1                 None                5         2.99     117
# 4              1                 None                6         2.99     130
# ..           ...                  ...              ...          ...     ...
# 995            1                 None                6         0.99     183
# 996            1                 None                4         0.99     179
# 997            1                 None                6         0.99     105
# 998            1                 None                5         2.99     101
# 999            1                 None                3         4.99      50
#
#      replacement_cost rating                         special_features  \
# 0               20.99     PG         Deleted Scenes,Behind the Scenes
# 1               12.99      G                  Trailers,Deleted Scenes
# 2               18.99  NC-17                  Trailers,Deleted Scenes
# 3               26.99      G           Commentaries,Behind the Scenes
# 4               22.99      G                           Deleted Scenes
# ..                ...    ...                                      ...
# 995              9.99      G               Trailers,Behind the Scenes
# 996             14.99  NC-17               Trailers,Behind the Scenes
# 997             10.99  NC-17                           Deleted Scenes
# 998             28.99      R                  Trailers,Deleted Scenes
# 999             18.99  NC-17  Trailers,Commentaries,Behind the Scenes
#
#             last_update
# 0   2006-02-15 05:03:42
# 1   2006-02-15 05:03:42
# 2   2006-02-15 05:03:42
# 3   2006-02-15 05:03:42
# 4   2006-02-15 05:03:42
# ..                  ...
# 995 2006-02-15 05:03:42
# 996 2006-02-15 05:03:42
# 997 2006-02-15 05:03:42
# 998 2006-02-15 05:03:42
# 999 2006-02-15 05:03:42
#
# [1000 rows x 13 columns]

# %%
df_merge = df_actor.merge(df_film_actor, on="actor_id", how="inner")
df_merge
# Out:
#       actor_id first_name last_name       last_update_x  film_id  \
# 0            1   PENELOPE   GUINESS 2006-02-15 04:34:33        1
# 1            1   PENELOPE   GUINESS 2006-02-15 04:34:33       23
# 2            1   PENELOPE   GUINESS 2006-02-15 04:34:33       25
# 3            1   PENELOPE   GUINESS 2006-02-15 04:34:33      106
# 4            1   PENELOPE   GUINESS 2006-02-15 04:34:33      140
# ...        ...        ...       ...                 ...      ...
# 5457       200      THORA    TEMPLE 2006-02-15 04:34:33      879
# 5458       200      THORA    TEMPLE 2006-02-15 04:34:33      912
# 5459       200      THORA    TEMPLE 2006-02-15 04:34:33      945
# 5460       200      THORA    TEMPLE 2006-02-15 04:34:33      958
# 5461       200      THORA    TEMPLE 2006-02-15 04:34:33      993
#
#            last_update_y
# 0    2006-02-15 05:05:03
# 1    2006-02-15 05:05:03
# 2    2006-02-15 05:05:03
# 3    2006-02-15 05:05:03
# 4    2006-02-15 05:05:03
# ...                  ...
# 5457 2006-02-15 05:05:03
# 5458 2006-02-15 05:05:03
# 5459 2006-02-15 05:05:03
# 5460 2006-02-15 05:05:03
# 5461 2006-02-15 05:05:03
#
# [5462 rows x 6 columns]

# %%
df_merge = df_film_actor.merge(df_actor[['actor_id','first_name', 'last_name']], on="actor_id", how="inner")
df_merge
# Out:
#       actor_id  film_id         last_update first_name last_name
# 0            1        1 2006-02-15 05:05:03   PENELOPE   GUINESS
# 1            1       23 2006-02-15 05:05:03   PENELOPE   GUINESS
# 2            1       25 2006-02-15 05:05:03   PENELOPE   GUINESS
# 3            1      106 2006-02-15 05:05:03   PENELOPE   GUINESS
# 4            1      140 2006-02-15 05:05:03   PENELOPE   GUINESS
# ...        ...      ...                 ...        ...       ...
# 5457       200      879 2006-02-15 05:05:03      THORA    TEMPLE
# 5458       200      912 2006-02-15 05:05:03      THORA    TEMPLE
# 5459       200      945 2006-02-15 05:05:03      THORA    TEMPLE
# 5460       200      958 2006-02-15 05:05:03      THORA    TEMPLE
# 5461       200      993 2006-02-15 05:05:03      THORA    TEMPLE
#
# [5462 rows x 5 columns]

# %%
df_merge = df_merge.merge(df_film[['film_id','title']], how="inner")
df_merge.head()
# Out:
#    actor_id  film_id         last_update first_name last_name  \
# 0         1        1 2006-02-15 05:05:03   PENELOPE   GUINESS
# 1         1       23 2006-02-15 05:05:03   PENELOPE   GUINESS
# 2         1       25 2006-02-15 05:05:03   PENELOPE   GUINESS
# 3         1      106 2006-02-15 05:05:03   PENELOPE   GUINESS
# 4         1      140 2006-02-15 05:05:03   PENELOPE   GUINESS
#
#                    title
# 0       ACADEMY DINOSAUR
# 1   ANACONDA CONFESSIONS
# 2            ANGELS LIFE
# 3  BULWORTH COMMANDMENTS
# 4          CHEAPER CLYDE

# %%
df_merge.groupby(["actor_id", "first_name", "last_name"])["title"].agg(["count"]).rename(columns={"count":"n_films_by_actor"})
# Out:
#                                   n_films_by_actor
# actor_id first_name last_name
# 1        PENELOPE   GUINESS                     19
# 2        NICK       WAHLBERG                    25
# 3        ED         CHASE                       22
# 4        JENNIFER   DAVIS                       22
# 5        JOHNNY     LOLLOBRIGIDA                29
# ...                                            ...
# 196      BELA       WALKEN                      30
# 197      REESE      WEST                        33
# 198      MARY       KEITEL                      40
# 199      JULIA      FAWCETT                     15
# 200      THORA      TEMPLE                      20
#
# [200 rows x 1 columns]

# %%
import pandas as pd
import requests
import io

# %%
url = "https://es.wikipedia.org/wiki/Poblaci%C3%B3n_humana_mundial"

# %%
r = requests.get(url)

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" lang="es" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Población humana mundial - Wikipedia, la enciclopedia libre</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available";var cookie=document.cookie.match(/(?:^|; )eswikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split(\'%2C\').forEach(function(pref){className=className.replace(new RegExp(\'(^| )\'+pref.replace(/-clientpref-\\w+$|[^\\w-]+/g,\'\')+\'-clientpref-\\\\w+( |$)\'),\'$1\'+pref+\'$2\');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\\t.","\xa0\\t,"],\n"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","enero","febrero","marzo","abril","mayo","junio","julio","agosto","septiembre","octubre","noviembre","diciembre"],"wgRequestId":"f51a81d5-3e1c-4a86-9fed-6c4b67690d68","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Población_humana_mundial","wgTitle":"Población humana mundial","wgCurRevisionId":162188439,"wgRevisionId":162188439,"wgArticleId":373818,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia:Artículos con enlaces externos rotos","Wikipedia:Páginas con enlaces mágicos de ISBN","Wikipedia:Páginas con plantillas con argumentos duplicados","Wikipedia:Artículos con identificadores GND","Conceptos demográficos","Geografía rural","Geografía de la población","Superpoblación","Mundialización sociocultural"],"wgPageViewLanguage":"es","wgPageContentLanguage":"es",\n"wgPageContentModel":"wikitext","wgRelevantPageName":"Población_humana_mundial","wgRelevantArticleId":373818,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgCiteReferencePreviewsActive":false,"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":6,"wgVisualEditor":{"pageLanguageCode":"es","pageLanguageDir":"ltr","pageVariantFallbacks":"es"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":true,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":80000,"wgULSCurrentAutonym":"español","wgRelatedArticlesCompat":[],"wgCentralAuthMobileDomain":false,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q11188","wgCheckUserClientHintsHeadersJsApi":["architecture","bitness",\n"brands","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":true,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"ext.gadget.imagenesinfobox":"read ...

# %%
df_lista = pd.read_html(io.StringIO(str(r.text)))

# %%
df_lista
# Out:
# [    Año Alta Fertilidad Media Fertilidad Baja Fertilidad Fuente
#  0  2030   9 052 218 435    8 701 741 117   8 363 524 014   [8]​
#  1  2040  10 505 469 051    9 707 730 574   8 967 760 761   [8]​
#  2  2050  12 192 025 720   10 830 020 294   9 615 651 599   [8]​
#  3  2060  14 149 343 588   12 082 055 499  10 310 350 393   [8]​
#  4  2070  16 420 890 881   13 478 835 784  11 055 238 859   [8]​
#  5  2080  19 057 114 250   15 037 094 815  11 853 943 036   [8]​
#  6  2090  22 116 559 095   16 775 500 800  12 710 350 929   [8]​
#  7  2100  25 667 169 739   18 714 880 138  13 628 631 438   [8]​,
#    Continente         Población (2024 est.)[9]​  \
#  0       Asia                     4 785 060 131
#  1     África                     1 494 993 923
#  2    América                     1 051 020 865
#  3     Europa                       741 651 866
#  4    Oceanía                        46 109 212
#  5  Antártida  4490 (no permanente, varía)[13]​
#
#    País más poblado (2024 est.)[10]​      Ciudad más poblada (2020 est.)
#  0             India (1 441 719 800)                  Tokio (37 400 000)
#  1             Nigeria (229 152 220)         El Cairo (21 323 000).[11]​
#  2      Estados Unidos (341 814 430)  Ciudad de México (23 077 000)[12]​
#  3               Rusia (143 957 090)                  Moscú (18 940 000)
#  4            Australia (26 699 488)                  Sídney (6 550 000)
#  5                     N.D.[nota 1]​                                N.D.  ,
#      Año Alta fertilidad Media fertilidad Baja fertilidad Fuente
#  0  2030   1 766 183 995    1 715 313 289   1 665 765 091  [14]​
#  1  2040   2 327 914 854    2 195 746 030   2 070 726 371  [14]​
#  2  2050   3 068 302 954    2 810 740 556   2 574 137 090  [14]​
#  3  2060   4 044 169 828    3 597 985 543   3 199 931 122  [14]​
#  4  2070   5 330 408 973    4 605 725 684   3 977 860 862  [14]​
#              Edad      Hombres      Mujeres Fuente
#  0      100- años      140 492      581 583  [15]​
#  1   95 - 99 años    1 267 671    3 670 143  [15]​
#  2   90 - 94 años    6 194 605   13 367 927  [15]​
#  3   85 - 89 años   18 233 518   31 250 902  [15]​
#  4   80 - 84 años   37 059 021   53 040 058  [15]​
#  5   75 - 79 años   65 167 882   83 250 699  [15]​
#  6   70 - 74 años  103 634 496  123 946 958  [15]​
#  7   65 - 69 años  137 638 922  154 453 307  [15]​
#  8   60 - 64 años  169 948 906  181 210 275  [15]​
#  9   55 - 59 años  207 127 190  212 733 178  [15]​
#  10  50 - 54 años  232 210 846  232 586 284  [15]​
#  11  45 - 49 años  240 114 725  236 673 086  [15]​
#  12  40 - 44 años  269 993 781  262 996 284  [15]​
#  13  35 - 39 años  298 612 034  288 227 513  [15]​
#  14  30 - 34 años  306 528 586  292 398 875  [15]​
#  15  25 - 29 años  304 860 341  287 526 797  [15]​
#  16  20 - 24 años  315 291 946  296 232 075  [15]​
#  17  15 - 19 años  332 007 571  311 182 871  [15]​
#  18  10 - 14 años  348 796 469  327 064 116  [15]​
#  19    5 - 9 años  349 534 148  329 407 713  [15]​
#  20    0 - 4 años  334 801 671  317 870 545  [15]​,
#                                 Región 2022 (porcentaje) 2030 (porcentaje)  \
#  0                 África Subsahariana    1.152 (14,51%)    1.401 (16,46%)
#  1  África del Norte y Asia occidental       549 (6,91%)       617 (7,25%)
#  2          Asia Central y Sur de Asia    2.075 (26,13%)    2.248 (26,41%)
#  3     Asia Oriental y Sudeste de Asia    2.342 (29,49%)    2.372 (27,87%)
#  4               Europa, EEUU y Canadá    1.120 (14,10%)    1.129 (13,26%)
#  5          América Latina y el Caribe       658 (8,29%)       695 (8,17%)
#  6             Australia/Nueva Zelanda        31 (0,39%)        34 (0,40%)
#  7                             Oceanía        14 (0,18%)        15 (0,18%)
#  8                               Mundo             7.942             8.512
#
#    2050 (porcentaje)
#  0    2.094 (21,62%)
#  1       771 (7,96%)
#  2    2.575 (26,58%)
#  3    2.317 (23,92%)
#  4    1.125 (11,61%)
#  5       749 (7,73%)
#  6        38 (0,39%)
#  7        20 (0,21%)
#  8             9.687  ,
#      Puesto País o territorio dependiente Población (2024 est.)[10]​
#  0      1.º                         India              1 441 720 000
#  1      2.º                         China              1 425 178 800
#  2      3.º                Estados Unidos                341 814 430
#  3      4.º                     Indonesia                279 798 050
#  4      5.º                      Pakistán                245 209 810
#  ..     ...                           ...                        ...
#  231  232.º                  Santa Helena                      5 286
#  232  233.º                    Montserrat                      4 397
#  233  234.º                Islas Malvinas                      3 823
#  234  235.º                          Niue                      1 953
#  235  236.º                       Tokelau                      1 937
#
#  [236 rows x 3 columns],
#            País o territorio dependiente Reclamado por  \
#  0                               Abjasia       Georgia
#  1                    República de China         China
#  2                                Kosovo        Serbia
#  3                      Chipre del Norte        Chipre
#  4  República Árabe Saharaui Democrática     Marruecos
#  5                        Osetia del Sur       Georgia
#
#    Población (2024 est.)[10]​
#  0                    244 926
#  18           711 (6.6%)    479 (4.4%)  72 (0.7%)
#  19           696 (6.4%)    485 (4.5%)  74 (0.7%)
#  20           680 (6.3%)    491 (4.5%)  75 (0.7%)  ,
#                Región       Edad media
#  0               Asia  31 años de edad
#  1             África  18 años de edad
#  2             Europa  42 años de edad
#  3  América del Norte  35 años de edad
#  4    América del Sur  31 años de edad
#  5            Oceanía  33 años de edad,
#                      Región Debajo de 15 años (proportion of population)  \
#  0                     Asia                                          24%
#  1                   África                                          41%
#  2                   Europa                                          16%
#  3  Latinoamérica-el Caribe                                          26%
#  4            EEUU y Canadá                                          19%
#  5                  Oceanía                                          23%
#  6                    Mundo                                          26%
#
#    Sobre los 65 años (proporción de población)
#  0                                          8%
#  1                                          3%
#  2                                         18%
#  3                                          8%
#  4                                         15%
#  5                                         12%
#  6                                          9%  ,
#     Ranking (2022)                             País  \
#  0               1                            Níger
#  1               2                           Angola
#  2               3                            Benín
#  3               4                             Mali
#  4               5                           Uganda
#  5               6                             Chad
#  6               7  República Democrática del Congo
#  7               8                          Somalia
#  8               9                    Sudán del Sur
#  9              10                       Mozambique
#
#     Tasa de natalidad más alta (2022)  (nacimientos anuales/1000 personas)
#  0                                              47.08
#  1                                              41.80
#  2                                              41.15
#  3                                              41.07
#  4                                              40.94
#  5                                              40.45
#  6                                              40.08
#  7                                              37.98
#  8                                              37.69
#  9                                              37.47                       ,
#                   0                                                  1  \
#  0              NaN  Ranking (2022) País Tasas de natalidad más baj...
#  1   Ranking (2022)                                               País
#  2                1                            Saint Pierre y Miquelón
#  3                2                                             Mónaco
#  4                3                                            Andorra
#  5                4                                      Corea del Sur
#  6                5                                              Japón
#  7                6                                             Italia
#  8                7                                             España
#  9                8                                             Taiwán
#  10               9                                             Grecia
#  11              10                                        Puerto Rico
#
#                                                      2
#  0                                                 NaN
#  1   Tasas de natalidad más bajas (2022)  (nacimien...
#  2                                                 647
#  3                                                 666
#  4                                                 688
#  5                                                 692
#  6                                                 695
#  7                                                 695
#  8                                                 713
#  9                                                 739
#  10                                                761
#  11                                                787  ,
#     Ranking (2022)                     País  \
#  0               1  Saint Pierre y Miquelón
#  1               2                   Mónaco
#  2               3                  Andorra
#  3               4            Corea del Sur
#  4               5                    Japón
#  5               6                   Italia
#  6               7                   España
#  7               8                   Taiwán
#  8               9                   Grecia
#  9              10              Puerto Rico
#
#     Tasas de natalidad más bajas (2022)  (nacimientos anuales/1000 personas)[nota 2]​
#  0                                                647
#  1                                                666
#  2                                                688
#  3                                                692
#  4                                                695
#  5                                                695
#  6                                                713
#  7                                                739
#  8                                                761
#  9                                                787                                  ,
#         Years  Tasa bruta de natalidad       Años  Tasa bruta de natalidad.1
#  0  1950–1955                      372  2000–2005                        212
#  1  1955–1960                      353  2005–2010                        203
#  2  1960–1965                      349  2010–2015                        194
#  3  1965–1970                      334  2015–2020                        182
#  4  1970–1975                      308  2020–2025                        169
#  5  1975–1980                      284  2025–2030                        158
#  6  1980–1985                      279  2030–2035                        150
#  7  1985–1990                      273  2035–2040                        145
#  8  1990–1995                      247  2040–2045                        140
#  9  1995–2000                      225  2045–2050                        134,
#                       Región  Tasa de fecundidad total (2010–2015)[45]​
#  0                     Mundo                                         25
#  1                    África                                         47
#  2       África Subsahariana                                         51
#  3         África Occidental                                         55
#  4            África central                                         58
#  5           África oriental                                         49
#  6          África del Norte                                         33
#  7            África del Sur                                         25
#  8                   Oceanía                                         24
#  9                      Asia                                         22
#  10                   Europa                                         16
#  11  Latinoamérica-el Caribe                                         22
#  12            EEUU y Canadá                                         19,
#                   0                                                  1  \
#  0              NaN  Ranking (2022) País Tasa de mortalidad más alt...
#  1   Ranking (2022)                                               País
#  2                1                                             Serbia
#  3                2                                            Rumania
#  4                3                                           Lituania
#  5                4                                            Letonia
#  6                5                                           Bulgaria
#  7                6                                            Ucrania
#  8                7                                              Rusia
#  9                8                                            Estonia
#  10               9                                        Bielorrusia
#  11              10                                            Croacia
#  12  Ranking (2022)                                               País
#  13               1                                              Catar
#  14               2                             Emiratos Árabes Unidos
#  15               3                                             Kuwait
#  16               4                                             Baréin
#  17               5                          Palestina, Franja de Gaza
#  18               6                                               Omán
#  19               7                             Palestina, Banco Oeste
#  20               8                                     Arabia Saudita
#  21               9                                              Libia
#  22              10                                           Jordania
#
#                                                      2
#  0   Ranking (2022) País Tasas de mortalidad más ba...
#  1   Tasa de mortalidad más alta (2022)  (muertes a...
#  2                                                1639
#  3                                                1526
#  4                                                1512
#  5                                                1465
#  6                                                1441
#  7                                                1377
#  8                                                1336
#  9                                                1310
#  10                                               1288
#  11                                               1288
#  12  Tasas de mortalidad más bajas (2022)  (muertes...
#  13                                                142
#  14                                                156
#  15                                                225
#  16                                                282
#  17                                                291
#  18                                                323
#  19                                                340
#  20                                                342
#  21                                                345
#  22                                                345  ,
#     Ranking (2022)         País  \
#  0               1       Serbia
#  1               2      Rumania
#  2               3     Lituania
#  3               4      Letonia
#  4               5     Bulgaria
#  5               6      Ucrania
#  6               7        Rusia
#  7               8      Estonia
#  8               9  Bielorrusia
#  9              10      Croacia
#
#     Tasa de mortalidad más alta (2022)  (muertes anuales/1000 personas)
#  0                                               1639
#  1                                               1526
#  2                                               1512
#  3                                               1465
#  4                                               1441
#  5                                               1377
#  6                                               1336
#  7                                               1310
#  8                                               1288
#  9                                               1288                    ,
#     Ranking (2022)                       País  \
#  0               1                      Catar
#  1               2     Emiratos Árabes Unidos
#  2               3                     Kuwait
#  3               4                     Baréin
#  4               5  Palestina, Franja de Gaza
#  5               6                       Omán
#  6               7     Palestina, Banco Oeste
#  7               8             Arabia Saudita
#  8               9                      Libia
#  9              10                   Jordania
#
#     Tasas de mortalidad más bajas (2022)  (muertes anuales/1000 personas)
#  0                                                142
#  1                                                156
#  2                                                225
#  3                                                282
#  4                                                291
#  5                                                323
#  6                                                340
#  7                                                342
#  8                                                345
#  9                                                345                      ,
#                          0                                                  1
#  0  Control de autoridades  Proyectos Wikimedia  Datos: Q11188  Multimedia...]

# %%
df = df_lista[0]
df.head()
# Out:
#     Año Alta Fertilidad Media Fertilidad Baja Fertilidad Fuente
# 0  2030   9 052 218 435    8 701 741 117   8 363 524 014   [8]​
# 1  2040  10 505 469 051    9 707 730 574   8 967 760 761   [8]​
# 2  2050  12 192 025 720   10 830 020 294   9 615 651 599   [8]​
# 3  2060  14 149 343 588   12 082 055 499  10 310 350 393   [8]​
# 4  2070  16 420 890 881   13 478 835 784  11 055 238 859   [8]​

# %%
df2 = df_lista[12]
df2.head()
# Out:
#   País o territorio Reclamado por Población (2024 est.)[10]​
# 0        Al-Shabaab       Somalia             7 000 - 12 000
# 1      Somalilandia       Somalia                  4 500 000
# 2        Puntlandia       Somalia                  2 700 000
# 3      Transnistria      Moldavia                    360 938

# %%
try:
    url = "https://www.campofrio.es/recetas"
    r = requests.get(url)
    df_lista = pd.read_html(io.StringIO(str(r.text)))
except ValueError as ex:
    print(f"No se han encontrado tablas:\n {ex}")
# Out:
# No se han encontrado tablas:
#  No tables found

# %%
df3 = df_lista[0]
df3
# Out:
#                                  Campofrío Food Group  \
# 0   La nueva planta de Campofrío en Burgos, inaugu...
# 1                                                Tipo
# 2                                           Industria
# 3                                              Género
# 4                                           Fundación
# 5                                        Sede central
# 6                                   Área de operación
# 7                                           Productos
# 8                                            Ingresos
# 9                                 Beneficio económico
# 10                                     Beneficio neto
# 11                                          Empleados
# 12                                     Empresa matriz
# 13                                          Sitio web
# 14                         [editar datos en Wikidata]
#
#                                Campofrío Food Group.1  \
# 0   La nueva planta de Campofrío en Burgos, inaugu...
# 1                                        alimentación
# 2                          procesado de los alimentos
# 3                                 elaboración cárnica
# 4                                      1952 en Burgos
# 5     Av de Europa, 24, 28108 Alcobendas, España [1]​
# 6                                              Europa
# 7                                  Productos cárnicos
# 8                   1830 millones de euros (2010)[2]​
# 9                    163 millones de euros (2010)[2]​
# 10                           40 millones de euros[2]​
# 11                                             11.800
# 12                                    Sigma Alimentos
# 13                       Página web oficial del grupo
# 14                         [editar datos en Wikidata]
#
#                                Campofrío Food Group.2
# 0   La nueva planta de Campofrío en Burgos, inaugu...
# 1                                        alimentación
# 2                          procesado de los alimentos
# 3                                 elaboración cárnica
# 4                                      1952 en Burgos
# 5     Av de Europa, 24, 28108 Alcobendas, España [1]​
# 6                                              Europa
# 7                                  Productos cárnicos
# 8                   1830 millones de euros (2010)[2]​
# 9                    163 millones de euros (2010)[2]​
# 10                           40 millones de euros[2]​
# 11                                             11.800
# 12                                    Sigma Alimentos
# 13                       Página web oficial del grupo
# 14                         [editar datos en Wikidata]

# %%
df = pd.read_csv(r"E:\Curso Data Science con Python - Numpy & Pandas\Datasets+Data+Science+con+Python+-+Pandas\6.9\SP500_data.csv", encoding = "ISO-8859-1", delimiter = ',')

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close